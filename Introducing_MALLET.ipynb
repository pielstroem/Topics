# %% [markdown]
# <div style="text-align: center"><h1>Topics – Easy Topic Modeling in Python</h1></div>

# %% [markdown]
# The text mining technique **Topic Modeling** has become a popular statistical method for clustering documents. This notebook introduces an user-friendly workflow, basically containing data preprocessing, an implementation of the prototypic topic model **Latent Dirichlet Allocation** (LDA) which learns the relationships between words, topics, and documents, as well as multiple visualizations to explore the trained LDA model.
#
# In this notebook, we're relying on the LDA implementation by [Andrew McCallum](https://people.cs.umass.edu/~mccallum/) called [**MALLET**](https://radimrehurek.com/gensim/).

# %% [markdown]
# ## First step: Installing dependencies
#
# The following tutorial will explain how to perform LDA topic modeling with a programming library in Python. If you have not done so yet, please install all necessary libraries by executing one of the following cells.
#
# **Note**: Make sure MALLET is properly installed or at least the unzipped folder in your working directory. If not, download from [this](http://mallet.cs.umass.edu/download.php) ressource.

# %% [markdown]
# ### Windows

# %%
#!pip install -r requirements.txt

# %% [markdown]
# ### macOS

# %%
#!pip3 install -r requirements.txt

# %% [markdown]
# ### Linux

# %%
#!sudo pip3 install -r requirements.txt

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# Let's not pay heed to any warnings right now and execute the following cell.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Loading modules from DARIAH-Topics library
# First, we have to get access to the functionalities of the library by importing them.

# %%
from dariah_topics import preprocessing
from dariah_topics import doclist
from dariah_topics import meta
from dariah_topics import mallet
from dariah_topics import visualization
# Out:
# /usr/local/lib/python3.5/dist-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)

# %% [markdown]
# #### Activating inline output in Jupyter notebook
# The following line will just tell the notebook to show graphics in the output frames.

# %%
# %matplotlib inline

# %% [markdown]
# ### 1.1. Reading a corpus of documents

# %% [markdown]
# #### Defining the path to the corpus folder
#
# In the present example code, we are using a folder of 'txt' documents provided with the package. For using your own corpus, change the path accordingly.

# %%
path = "grenzboten_sample"

# %% [markdown]
# #### List all documents in the folder
# We begin by creating a list of all the documents in the folder specified above. That list will tell function `pre.read_from_txt()` (see below) which text documents to read.

# %%
pathdoclist = doclist.PathDocList(path)
document_list = pathdoclist.full_paths(as_str=True)

# %% [markdown]
# The current list of documents looks like this:

# %%
document_list
# Out:
# ['grenzboten_sample/Grenzboten_1845_Tagebuch_52.txt',
#  'grenzboten_sample/Grenzboten_1916_Kriegstagebuch_48.txt',
#  'grenzboten_sample/Grenzboten_1916_Kriegstagebuch_81.txt',
#  'grenzboten_sample/Grenzboten_1915_Kriegstagebuch_73.txt',
#  'grenzboten_sample/Grenzboten_1914_Kriegstagebuch_97.txt',
#  'grenzboten_sample/Grenzboten_1846_Tagebuch_88.txt',
#  'grenzboten_sample/Grenzboten_1844_Tagebuch_56.txt',
#  'grenzboten_sample/Grenzboten_1844_Tagebuch_77.txt',
#  'grenzboten_sample/Grenzboten_1916_Kriegstagebuch_49.txt',
#  'grenzboten_sample/Grenzboten_1846_Tagebuch_96.txt',
#  'grenzboten_sample/Grenzboten_1846_Tagebuch_82.txt',
#  'grenzboten_sample/Grenzboten_1844_Tagebuch_88.txt',
#  'grenzboten_sample/Grenzboten_1915_Kriegstagebuch_39.txt',
#  'grenzboten_sample/Grenzboten_1915_Kriegstagebuch_94.txt',
#  'grenzboten_sample/Grenzboten_1914_Kriegstagebuch_37.txt',
#  'grenzboten_sample/Grenzboten_1845_Tagebuch_81.txt',
#  'grenzboten_sample/Grenzboten_1845_Tagebuch_93.txt',
#  'grenzboten_sample/Grenzboten_1914_Kriegstagebuch_94.txt',
#  'grenzboten_sample/Grenzboten_1845_Tagebuch_62.txt',
#  'grenzboten_sample/Grenzboten_1845_Tagebuch_85.txt',
#  'grenzboten_sample/Grenzboten_1914_Kriegstagebuch_68.txt',
#  'grenzboten_sample/Grenzboten_1844_Tagebuch_70.txt',
#  'grenzboten_sample/Grenzboten_1916_Kriegstagebuch_41.txt',
#  'grenzboten_sample/Grenzboten_1916_Kriegstagebuch_69.txt',
#  'grenzboten_sample/Grenzboten_1846_Tagebuch_51.txt',
#  'grenzboten_sample/Grenzboten_1914_Kriegstagebuch_95.txt',
#  'grenzboten_sample/Grenzboten_1915_Kriegstagebuch_99.txt',
#  'grenzboten_sample/Grenzboten_1846_Tagebuch_72.txt',
#  'grenzboten_sample/Grenzboten_1844_Tagebuch_82.txt',
#  'grenzboten_sample/Grenzboten_1915_Kriegstagebuch_33.txt']

# %% [markdown]
# **Alternatively**, if we want to use other documents, or just a selction of those in the specified folder, we can define our own `doclist` by creating a list of strings containing paths to text files. For example, to use only the texts from 1916, we would define the list as
#
# `
#     doclist = ['grenzboten_sample/grenzboten_1916_Kriegstagebuch_41.txt',
#            'grenzboten_sample/grenzboten_1916_Kriegstagebuch_48.txt',
#            'grenzboten_sample/grenzboten_1916_Kriegstagebuch_49.txt',
#            'grenzboten_sample/grenzboten_1916_Kriegstagebuch_69.txt',
#            'grenzboten_sample/grenzboten_1916_Kriegstagebuch_81.txt']
# `

# %% [markdown]
# #### Generate document labels

# %%
document_labels = pathdoclist.labels()
document_labels
# Out:
# ['Grenzboten_1845_Tagebuch_52',
#  'Grenzboten_1916_Kriegstagebuch_48',
#  'Grenzboten_1916_Kriegstagebuch_81',
#  'Grenzboten_1915_Kriegstagebuch_73',
#  'Grenzboten_1914_Kriegstagebuch_97',
#  'Grenzboten_1846_Tagebuch_88',
#  'Grenzboten_1844_Tagebuch_56',
#  'Grenzboten_1844_Tagebuch_77',
#  'Grenzboten_1916_Kriegstagebuch_49',
#  'Grenzboten_1846_Tagebuch_96',
#  'Grenzboten_1846_Tagebuch_82',
#  'Grenzboten_1844_Tagebuch_88',
#  'Grenzboten_1915_Kriegstagebuch_39',
#  'Grenzboten_1915_Kriegstagebuch_94',
#  'Grenzboten_1914_Kriegstagebuch_37',
#  'Grenzboten_1845_Tagebuch_81',
#  'Grenzboten_1845_Tagebuch_93',
#  'Grenzboten_1914_Kriegstagebuch_94',
#  'Grenzboten_1845_Tagebuch_62',
#  'Grenzboten_1845_Tagebuch_85',
#  'Grenzboten_1914_Kriegstagebuch_68',
#  'Grenzboten_1844_Tagebuch_70',
#  'Grenzboten_1916_Kriegstagebuch_41',
#  'Grenzboten_1916_Kriegstagebuch_69',
# 7   grenzboten_sample/Grenzboten_1844_Tagebuch_77.txt        1844_Tagebuch_77
# 8   grenzboten_sample/Grenzboten_1916_Kriegstagebu...  1916_Kriegstagebuch_49
# 9   grenzboten_sample/Grenzboten_1846_Tagebuch_96.txt        1846_Tagebuch_96
# 10  grenzboten_sample/Grenzboten_1846_Tagebuch_82.txt        1846_Tagebuch_82
# 11  grenzboten_sample/Grenzboten_1844_Tagebuch_88.txt        1844_Tagebuch_88
# 12  grenzboten_sample/Grenzboten_1915_Kriegstagebu...  1915_Kriegstagebuch_39
# 13  grenzboten_sample/Grenzboten_1915_Kriegstagebu...  1915_Kriegstagebuch_94
# 14  grenzboten_sample/Grenzboten_1914_Kriegstagebu...  1914_Kriegstagebuch_37
# 15  grenzboten_sample/Grenzboten_1845_Tagebuch_81.txt        1845_Tagebuch_81
# 16  grenzboten_sample/Grenzboten_1845_Tagebuch_93.txt        1845_Tagebuch_93
# 17  grenzboten_sample/Grenzboten_1914_Kriegstagebu...  1914_Kriegstagebuch_94
# 18  grenzboten_sample/Grenzboten_1845_Tagebuch_62.txt        1845_Tagebuch_62
# 19  grenzboten_sample/Grenzboten_1845_Tagebuch_85.txt        1845_Tagebuch_85
# 20  grenzboten_sample/Grenzboten_1914_Kriegstagebu...  1914_Kriegstagebuch_68
# 21  grenzboten_sample/Grenzboten_1844_Tagebuch_70.txt        1844_Tagebuch_70
# 22  grenzboten_sample/Grenzboten_1916_Kriegstagebu...  1916_Kriegstagebuch_41
# 23  grenzboten_sample/Grenzboten_1916_Kriegstagebu...  1916_Kriegstagebuch_69
# 24  grenzboten_sample/Grenzboten_1846_Tagebuch_51.txt        1846_Tagebuch_51
# 25  grenzboten_sample/Grenzboten_1914_Kriegstagebu...  1914_Kriegstagebuch_95
# 26  grenzboten_sample/Grenzboten_1915_Kriegstagebu...  1915_Kriegstagebuch_99
# 27  grenzboten_sample/Grenzboten_1846_Tagebuch_72.txt        1846_Tagebuch_72
# 28  grenzboten_sample/Grenzboten_1844_Tagebuch_82.txt        1844_Tagebuch_82
# 29  grenzboten_sample/Grenzboten_1915_Kriegstagebu...  1915_Kriegstagebuch_33

# %% [markdown]
# #### Read listed documents from folder

# %%
corpus = preprocessing.read_from_txt(document_list)

# %% [markdown]
# At this point, the corpus is generator object.

# %% [markdown]
# ### 1.3. Tokenize corpus
# Your text files will be tokenized. Tokenization is the task of cutting a stream of characters into linguistic units, simply words or, more precisely, tokens. The tokenize function the library provides is a simple unicode tokenizer. Depending on the corpus it might be useful to use an external tokenizer function, or even develop your own, since its efficiency varies with language, epoch and text type.

# %%
tokens = [list(preprocessing.tokenize(document)) for document in list(corpus)]

# %% [markdown]
# At this point, each text is represented by a list of separate token strings. If we want to look e.g. into the first text (which has the index `0` as Python starts counting at 0) and show its first 10 words/tokens (that have the indeces `0:9` accordingly) by typing:

# %%
tokens[0][0:9]
# Out:
# ['es',
#  'berlin',
#  'und',
#  'paris',
#  'sprcchscligkeir',
#  'credit',
#  'und',
#  'religion',
#  'priester']

# %% [markdown]
# ### 1.4.1 Create a document-term matrix
#
# %% [markdown]
# #### Create Dictionaries

# %%
id_types = preprocessing.create_dictionary(tokens)
doc_ids = preprocessing.create_dictionary(document_labels)

# %% [markdown]
# #### Create matrix market

# %%
sparse_bow = preprocessing.create_sparse_bow(document_labels, tokens, id_types, doc_ids)

# %% [markdown]
# ### 1.5. Feature selection and/or removal
#
# In topic modeling, it is often usefull (if not vital) to remove some types before modeling. In this example, the 100 most frequent words and the *hapax legomena* in the corpus are listed and removed. Alternatively, the 'feature_list' containing all features to be removed from the corpus can be replaced by, or combined with an external stop word list or any other list of strings containing features we want to remove.
#
# **Note**: For small/normal corpora using a **`doc_term_matrix` (1.5.1)** will be easier to handle. Using **`sparse_bow` (1.5.2)** is recommended for large corpora only.

# %% [markdown]
# ### 1.5.1 Remove features from `doc_term_matrix`

# %% [markdown]
# #### List the 100 most frequent words

# %%
mfw100 = preprocessing.find_stopwords(doc_terms, 100)

# %% [markdown]
# These are the five most frequent words:

# %%
mfw100[:5]
# Out:
# ['die', 'der', 'und', 'in', 'den']

# %% [markdown]
# #### List hapax legomena

# %%
hapax_list = preprocessing.find_hapax(doc_terms)

# %% [markdown]
# #### Optional: Use external stopwordlist

# %%
path_to_stopwordlist = "tutorial_supplementals/stopwords/en.txt"

extern_stopwords = [line.strip() for line in open(path_to_stopwordlist, 'r')]

# %% [markdown]
# #### Combine lists and remove content from `doc_term_matrix`

# %%
features = set(mfw100 + hapax_list + extern_stopwords)
doc_terms = preprocessing.remove_features(doc_terms, features)

# %% [markdown]
# Finally, this is how your clean corpus looks like now.

# %%
doc_terms
# Out:
#                                     ihr  immer  franzosen  genommen  ganz  \
# Grenzboten_1844_Tagebuch_56         4.0    3.0        0.0       1.0   7.0
# Grenzboten_1844_Tagebuch_70        10.0   10.0        2.0       1.0   8.0
# Grenzboten_1844_Tagebuch_77         7.0    7.0        0.0       1.0   4.0
# Grenzboten_1844_Tagebuch_82         1.0    8.0        0.0       0.0   6.0
# Grenzboten_1844_Tagebuch_88         3.0    2.0        2.0       0.0   2.0
# Grenzboten_1845_Tagebuch_52         8.0   15.0        4.0       1.0  10.0
# Grenzboten_1845_Tagebuch_62         3.0   14.0        3.0       2.0  10.0
# Grenzboten_1845_Tagebuch_81        15.0   14.0        1.0       3.0  13.0
# Grenzboten_1845_Tagebuch_85         6.0   10.0        1.0       2.0   7.0
# Grenzboten_1845_Tagebuch_93        14.0    7.0        1.0       1.0   3.0
# Grenzboten_1846_Tagebuch_51        19.0    8.0        1.0       1.0   7.0
# Grenzboten_1846_Tagebuch_72         5.0    7.0        4.0       0.0   8.0
# Grenzboten_1846_Tagebuch_82        19.0   11.0        4.0       2.0  16.0
# Grenzboten_1846_Tagebuch_88         3.0    8.0        1.0       2.0  10.0
# Grenzboten_1846_Tagebuch_96        23.0   14.0       10.0       3.0  20.0
# Grenzboten_1914_Kriegstagebuch_37   0.0    0.0        6.0       1.0   0.0
# Grenzboten_1914_Kriegstagebuch_68   0.0    0.0        8.0       3.0   0.0
# Grenzboten_1915_Kriegstagebuch_99       0.0        0.0           0.0
# Grenzboten_1916_Kriegstagebuch_41       0.0        0.0           0.0
# Grenzboten_1916_Kriegstagebuch_48       0.0        0.0           0.0
# Grenzboten_1916_Kriegstagebuch_49       0.0        0.0           0.0
# Grenzboten_1916_Kriegstagebuch_69       0.0        0.0           0.0
# Grenzboten_1916_Kriegstagebuch_81       0.0        0.0           2.0
#
#                                    tendenzstück  gemeingefährlichkeitsmaßstab
# Grenzboten_1844_Tagebuch_56                 0.0                           0.0
# Grenzboten_1844_Tagebuch_70                 0.0                           2.0
# Grenzboten_1844_Tagebuch_77                 0.0                           0.0
# Grenzboten_1844_Tagebuch_82                 0.0                           0.0
# Grenzboten_1844_Tagebuch_88                 0.0                           0.0
# Grenzboten_1845_Tagebuch_52                 2.0                           0.0
# Grenzboten_1845_Tagebuch_62                 0.0                           0.0
# Grenzboten_1845_Tagebuch_81                 0.0                           0.0
# Grenzboten_1845_Tagebuch_85                 0.0                           0.0
# Grenzboten_1845_Tagebuch_93                 0.0                           0.0
# Grenzboten_1846_Tagebuch_51                 0.0                           0.0
# Grenzboten_1846_Tagebuch_72                 0.0                           0.0
# Grenzboten_1846_Tagebuch_82                 0.0                           0.0
# Grenzboten_1846_Tagebuch_88                 0.0                           0.0
# Grenzboten_1846_Tagebuch_96                 0.0                           0.0
# Grenzboten_1914_Kriegstagebuch_37           0.0                           0.0
# Grenzboten_1914_Kriegstagebuch_68           0.0                           0.0
# Grenzboten_1914_Kriegstagebuch_94           0.0                           0.0
# Grenzboten_1914_Kriegstagebuch_95           0.0                           0.0
# Grenzboten_1914_Kriegstagebuch_97           0.0                           0.0
# Grenzboten_1915_Kriegstagebuch_33           0.0                           0.0
# Grenzboten_1915_Kriegstagebuch_39           0.0                           0.0
# Grenzboten_1915_Kriegstagebuch_73           0.0                           0.0
# Grenzboten_1915_Kriegstagebuch_94           0.0                           0.0
# Grenzboten_1915_Kriegstagebuch_99           0.0                           0.0
# Grenzboten_1916_Kriegstagebuch_41           0.0                           0.0
# Grenzboten_1916_Kriegstagebuch_48           0.0                           0.0
# Grenzboten_1916_Kriegstagebuch_49           0.0                           0.0
# Grenzboten_1916_Kriegstagebuch_69           0.0                           0.0
# Grenzboten_1916_Kriegstagebuch_81           0.0                           0.0
#
# [30 rows x 4588 columns]

# %% [markdown]
# ### 1.5.2 Remove features from `sparse_bow`

# %% [markdown]
# #### List the 100 most frequent words

# %%
mfw100 = preprocessing.find_stopwords(sparse_bow, 100, id_types)

# %% [markdown]
# These are the five most frequent words:

# %%
mfw100[:5]
# Out:
# ['die', 'der', 'und', 'in', 'den']

# %% [markdown]
# #### List hapax legomena

# %%
hapax_list = preprocessing.find_hapax(sparse_bow, id_types)

# %% [markdown]
# #### Optional: Use external stopwordlist

# %%
path_to_stopwordlist = "tutorial_supplementals/stopwords/en.txt"

extern_stopwords = [line.strip() for line in open(path_to_stopwordlist, 'r')]

# %% [markdown]
# #### Combine lists

# %%
features = set(mfw100 + hapax_list + extern_stopwords)

# %% [markdown]
# #### Remove features from files

# %%
tokens_cleaned = []

for document in tokens:
    document_clean = preprocessing.remove_features_from_file(document, list(features))
    tokens_cleaned.append(list(document_clean))

# %% [markdown]
# #### Write MALLET import files

# %%
preprocessing.create_mallet_import(tokens_cleaned, document_labels)

# %% [markdown]
# ## 1. Setting the parameters

# %% [markdown]
# #### Define path to corpus folder

# %%
path_to_corpus = "tutorial_supplementals/mallet_input"

# %% [markdown]
# #### Path to mallet folder
#
# Now we must tell the library where to find the local instance of mallet. If you managed to install Mallet, it is sufficient set `path_to_mallet = "mallet"`, if you just store Mallet in a local folder, you have to specify the path to the binary explictly.

# %%
path_to_mallet = 'mallet'

# %% [markdown]
# #### Output folder

# %%
outfolder = "tutorial_supplementals/mallet_output"
binary = "tutorial_supplementals/mallet_output/binary.mallet"

# %% [markdown]
# #### The Mallet corpus model
#
# Finally, we can give all these folder paths to a Mallet function that handles all the preprocessing steps and creates a Mallet-specific corpus model object.

# %%
# %%time

mallet_binary = mallet.create_mallet_binary(path_to_mallet=path_to_mallet,
                                            path_to_corpus=path_to_corpus,
                                            output_file=binary)
# Out:
# CPU times: user 2.63 ms, sys: 9.61 ms, total: 12.2 ms
# Wall time: 912 ms

# %% [markdown]
# ## 2. Model creation

# %% [markdown]
# We can define the number of topics we want to calculate as an argument (`num_topics`) in the function. Furthermore, the number of iterations (`num_iterations`) can be defined. A higher number of iterations will probably yield a better model, but also increases processing time.
#
# **Warning: this step can take quite a while!** Meaning something between some seconds and some hours depending on corpus size and the number of iterations. Our example short stories corpus should be done within a minute or two at `num_iterations=5000`.

# %%
# %%time

mallet.create_mallet_model(path_to_mallet=path_to_mallet, 
                           path_to_binary=mallet_binary, 
                           folder_for_output=outfolder,
                           num_iterations=5000,
                           num_topics=10)
# Out:
# CPU times: user 38.3 ms, sys: 25.7 ms, total: 64 ms
# Wall time: 35.1 s

# %% [markdown]
# ### 2.4. Create document-topic matrix
#
# The generated model object can now be translated into a human-readable document-topic matrix (that is a actually a pandas data frame) that constitutes our principle exchange format for topic modeling results. For generating the matrix from a Gensim model, we can use the following function:

# %%
doc_topic = mallet.show_doc_topic_matrix(outfolder)
doc_topic
# Out:
#                                Grenzboten_1844_Tagebuch_56.txt  \
# ihr sondern ihn                                       0.141102
# neuen berlin immer                                    0.205508
# januar genommen september                             0.016525
# dieses worden scheint                                 0.105508
# könig deutschland oesterreich                         0.047034
# eben vom wien                                         0.086864
# ohne wurde seinen                                     0.194492
# ihnen diesen frankreich                               0.084322
# südlich juli nördlich                                 0.000424
# nichts alles machen                                   0.118220
#
#                                Grenzboten_1844_Tagebuch_70.txt  \
# ihr sondern ihn                                       0.168394
# neuen berlin immer                                    0.205699
# januar genommen september                             0.009499
# dieses worden scheint                                 0.118653
# könig deutschland oesterreich                         0.065112
# eben vom wien                                         0.152850
# ohne wurde seinen                                     0.125907
# ihnen diesen frankreich                               0.054059
# südlich juli nördlich                                 0.000173
# nichts alles machen                                   0.099655
#
#                                Grenzboten_1844_Tagebuch_77.txt  \
# ihr sondern ihn                                       0.121576
# neuen berlin immer                                    0.211336
# januar genommen september                             0.009060
# dieses worden scheint                                 0.082807
# könig deutschland oesterreich                         0.086178
# eben vom wien                                         0.107248
# ohne wurde seinen                                     0.210493
# ihnen diesen frankreich                               0.077328
# südlich juli nördlich                                 0.000211
# nichts alles machen                                   0.093763
#
#                                Grenzboten_1844_Tagebuch_82.txt  \
# ihr sondern ihn                                       0.123397
# neuen berlin immer                                    0.155093
# januar genommen september                             0.008369
# dieses worden scheint                                 0.100605
# könig deutschland oesterreich                         0.059651
# eben vom wien                                         0.112714
# ohne wurde seinen                                     0.262642
# ihnen diesen frankreich                               0.067130
# südlich juli nördlich                                 0.002671
# nichts alles machen                                   0.107728
#
#                                Grenzboten_1844_Tagebuch_88.txt  \
# ihr sondern ihn                                       0.144249
# neuen berlin immer                                    0.019944
# januar genommen september                             0.009740
# dieses worden scheint                                 0.041280
# könig deutschland oesterreich                         0.070965
# eben vom wien                                         0.384508
# ohne wurde seinen                                     0.118275
# ihnen diesen frankreich                               0.080241
# südlich juli nördlich                                 0.003247
# nichts alles machen                                   0.127551
#
#                                Grenzboten_1845_Tagebuch_52.txt  \
# ihr sondern ihn                                       0.118045
# neuen berlin immer                                    0.100333
# januar genommen september                             0.010523
# dieses worden scheint                                 0.109294
# könig deutschland oesterreich                         0.074495
# eben vom wien                                         0.193895
# ohne wurde seinen                                     0.189310
# ihnen diesen frankreich                               0.085539
# südlich juli nördlich                                 0.000938
# nichts alles machen                                   0.117629
#
#                                Grenzboten_1845_Tagebuch_62.txt  \
# ihr sondern ihn                                       0.088978
# neuen berlin immer                                    0.056001
# januar genommen september                             0.002822
# dieses worden scheint                                 0.086007
# könig deutschland oesterreich                         0.043523
# eben vom wien                                         0.123737
# ohne wurde seinen                                     0.191771
# ihnen diesen frankreich                               0.053327
# südlich juli nördlich                                 0.000743
# nichts alles machen                                   0.353090
#
#                                Grenzboten_1845_Tagebuch_81.txt  \
# ihr sondern ihn                                       0.156493
# neuen berlin immer                                    0.065729
# januar genommen september                             0.002858
# dieses worden scheint                                 0.280864
# könig deutschland oesterreich                         0.022977
# eben vom wien                                         0.113740
# ohne wurde seinen                                     0.193759
# ihnen diesen frankreich                               0.048811
# südlich juli nördlich                                 0.001257
# nichts alles machen                                   0.113512
#
#                                Grenzboten_1845_Tagebuch_85.txt  \
# ihr sondern ihn                                       0.126174
# neuen berlin immer                                    0.068421
# januar genommen september                             0.009246
# dieses worden scheint                                 0.253343
# könig deutschland oesterreich                         0.052205
# eben vom wien                                         0.111380
# ohne wurde seinen                                     0.226031
# ihnen diesen frankreich                               0.061593
# südlich juli nördlich                                 0.001280
# nichts alles machen                                   0.090327
#
#                                Grenzboten_1845_Tagebuch_93.txt  \
# ihr sondern ihn                                       0.134758
# neuen berlin immer                                    0.043624
# januar genommen september                             0.010067
# dieses worden scheint                                 0.087072
# könig deutschland oesterreich                         0.225539
# eben vom wien                                         0.042564
# ohne wurde seinen                                     0.186683
# ihnen diesen frankreich                               0.081067
# südlich juli nördlich                                 0.000530
# nichts alles machen                                   0.188096
#
#                                                ...                    \
# ihr sondern ihn                                ...
# neuen berlin immer                             ...
# januar genommen september                      ...
# dieses worden scheint                          ...
# könig deutschland oesterreich                  ...
# eben vom wien                                  ...
# ohne wurde seinen                              ...
# ihnen diesen frankreich                        ...
# südlich juli nördlich                          ...
# nichts alles machen                            ...
#
#                                Grenzboten_1915_Kriegstagebuch_33.txt  \
# ihr sondern ihn                                             0.000354
# neuen berlin immer                                          0.002477
# januar genommen september                                   0.569356
# dieses worden scheint                                       0.003892
# könig deutschland oesterreich                               0.016631
# eben vom wien                                               0.008846
# ohne wurde seinen                                           0.028662
# ihnen diesen frankreich                                     0.003185
# südlich juli nördlich                                       0.366242
# nichts alles machen                                         0.000354
#
#                                Grenzboten_1915_Kriegstagebuch_39.txt  \
# ihr sondern ihn                                             0.007647
# neuen berlin immer                                          0.000588
# januar genommen september                                   0.332353
# dieses worden scheint                                       0.001765
# könig deutschland oesterreich                               0.008824
# eben vom wien                                               0.001765
# ohne wurde seinen                                           0.033529
# ihnen diesen frankreich                                     0.002941
# südlich juli nördlich                                       0.606471
# nichts alles machen                                         0.004118
#
#                                Grenzboten_1915_Kriegstagebuch_73.txt  \
# ihr sondern ihn                                             0.031832
# neuen berlin immer                                          0.006988
# januar genommen september                                   0.333075
# dieses worden scheint                                       0.000776
# könig deutschland oesterreich                               0.008540
# eben vom wien                                               0.000776
# ohne wurde seinen                                           0.000776
# ihnen diesen frankreich                                     0.011646
# südlich juli nördlich                                       0.601708
# nichts alles machen                                         0.003882
#
#                                Grenzboten_1915_Kriegstagebuch_94.txt  \
# ihr sondern ihn                                             0.004076
# neuen berlin immer                                          0.006793
# januar genommen september                                   0.387228
# dieses worden scheint                                       0.006793
# könig deutschland oesterreich                               0.006793
# eben vom wien                                               0.004076
# ohne wurde seinen                                           0.006793
# ihnen diesen frankreich                                     0.009511
# südlich juli nördlich                                       0.561141
# nichts alles machen                                         0.006793
#
#                                Grenzboten_1915_Kriegstagebuch_99.txt  \
# ihr sondern ihn                                             0.004814
# neuen berlin immer                                          0.002063
# januar genommen september                                   0.431224
# dieses worden scheint                                       0.004814
# könig deutschland oesterreich                               0.035076
# eben vom wien                                               0.000688
# ohne wurde seinen                                           0.002063
# ihnen diesen frankreich                                     0.000688
# südlich juli nördlich                                       0.517882
# nichts alles machen                                         0.000688
#
#                                Grenzboten_1916_Kriegstagebuch_41.txt  \
# ihr sondern ihn                                             0.005777
# neuen berlin immer                                          0.013479
# januar genommen september                                   0.136714
# dieses worden scheint                                       0.000642
# könig deutschland oesterreich                               0.010911
# eben vom wien                                               0.007060
# ohne wurde seinen                                           0.013479
# ihnen diesen frankreich                                     0.000642
# südlich juli nördlich                                       0.809371
# nichts alles machen                                         0.001926
#
#                                Grenzboten_1916_Kriegstagebuch_48.txt  \
# ihr sondern ihn                                             0.006962
# neuen berlin immer                                          0.001899
# januar genommen september                                   0.128481
# dieses worden scheint                                       0.009494
# könig deutschland oesterreich                               0.001899
# eben vom wien                                               0.000633
# ohne wurde seinen                                           0.004430
# ihnen diesen frankreich                                     0.008228
# südlich juli nördlich                                       0.828481
# nichts alles machen                                         0.009494
#
#                                Grenzboten_1916_Kriegstagebuch_49.txt  \
# ihr sondern ihn                                             0.002525
# neuen berlin immer                                          0.001515
# januar genommen september                                   0.121717
# dieses worden scheint                                       0.010606
# könig deutschland oesterreich                               0.007576
# eben vom wien                                               0.000505
# ohne wurde seinen                                           0.008586
# ihnen diesen frankreich                                     0.000505
# südlich juli nördlich                                       0.841919
# nichts alles machen                                         0.004545
#
#                                Grenzboten_1916_Kriegstagebuch_69.txt  \
# ihr sondern ihn                                             0.000552
# neuen berlin immer                                          0.004972
# januar genommen september                                   0.112155
# dieses worden scheint                                       0.000552
# könig deutschland oesterreich                               0.006077
# eben vom wien                                               0.001657
# ohne wurde seinen                                           0.013812
# ihnen diesen frankreich                                     0.000552
# südlich juli nördlich                                       0.851381
# nichts alles machen                                         0.008287
#
#                                Grenzboten_1916_Kriegstagebuch_81.txt
# ihr sondern ihn                                             0.001634
# neuen berlin immer                                          0.003813
# januar genommen september                                   0.138889
# dieses worden scheint                                       0.002723
# könig deutschland oesterreich                               0.017974
# eben vom wien                                               0.004902
# ohne wurde seinen                                           0.025599
# ihnen diesen frankreich                                     0.000545
# südlich juli nördlich                                       0.799020
# nichts alles machen                                         0.004902
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 3. Visualization

# %% [markdown]
# Now we can see the topics in the model with the following function:
#
# **Hint:** Depending on the number of topics chosen in step 2, you might have to adjust *num_topics* in this step accordingly.

# %%
mallet.show_topics_keys("tutorial_supplementals/mallet_output", num_topics=10)
# Out:
#             Key 1        Key 2        Key 3       Key 4     Key 5       Key 6  \
# Topic 1       ihr      sondern          ihn       keine      ganz      können
# Topic 2     neuen       berlin        immer        dies     jahre     polizei
# Topic 3    januar     genommen    september     mehrere  dezember     besetzt
# Topic 4    dieses       worden      scheint    hiesigen     indem       seite
# Topic 5     könig  deutschland  oesterreich       kunst     erste       ihnen
# Topic 6      eben          vom         wien      einige    einmal      wissen
# Topic 7      ohne        wurde       seinen        wohl    lassen       hatte
# Topic 8     ihnen       diesen   frankreich       ihrer      dies      worden
# Topic 9   südlich         juli     nördlich  abgewiesen      märz  feindliche
# Topic 10   nichts        alles       machen         nun      habe       herrn
#
#                   Key 7       Key 8      Key 9     Key 10
# Topic 1           würde      seinem     andern      deren
# Topic 2           tagen       sieht       ganz        mag
# Topic 3       franzosen  abgewiesen    angriff    erobert
# Topic 4         bereits      beiden     sollte   geworden
# Topic 5       professor       große       dort  friedrich
# Topic 6           wenig      wiener      steht      gewiß
# Topic 7          diesem        viel       wäre       soll
# Topic 8   französischen      wurden     kommen        sei
# Topic 9    abgeschlagen       april  geschütze   zwischen
# Topic 10           kein         gar      etwas        mir

# %% [markdown]
# ### 3.1. Distribution of topics

# %% [markdown]
# #### Distribution of topics over all documents
#
# The distribution of topics over all documents can now be visualized in a heat map.Note: Plot will be shown in a seperate tab.

# %%
visualization.doc_topic_heatmap_interactive(doc_topic, title="Grenzbote")

# %% [markdown]
# #### Distribution of topics in a single documents
#
# To take closer look on the topics in a single text, we can use the follwing function that shows all the topics in a text and their respective proportions. To select the document, we have to give its index to the function.

# %%
visualization.plot_doc_topics(doc_topic, 0)
# Out:
# <module 'matplotlib.pyplot' from '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/pyplot.py'>
